# %%
import pandas as pd
df=pd.read_csv('data.csv')
df

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   empid    9 non-null      int64
#  1   ename    8 non-null      object
#  2   sal      8 non-null      float64
#  3   address  7 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 420.0+ bytes
#           empid         sal
# count  9.000000     8.00000
# mean   5.000000  2744.25000
# std    2.738613  1312.22687
# min    1.000000   900.00000
# 25%    3.000000  1971.25000
# 50%    5.000000  2316.50000
# 75%    7.000000  3711.75000
# max    9.000000  4555.00000

# %%
df.shape
# Out:
# (5, 4)

# %%
df.head()
# Out:
#    empid ename   sal  address
# 0      1     a  2300  kolkata
# 1      2     b   900   mumbai
# 2      3     c  1999    delhi
# 3      4     d  1888  chennai
# 4      5     r  1999     pune

# %%
df.head(3)
# Out:
#    empid ename   sal  address
# 0      1     a  2300  kolkata
# 1      2     b   900   mumbai
# 2      3     c  1999    delhi

# %%
df[0:5]
# Out:
#    empid ename   sal  address
# 0      1     a  2300  kolkata
# 1      2     b   900   mumbai
# 2      3     c  1999    delhi
# 3      4     d  1888  chennai
# 4      5     r  1999     pune

# %%
df.columns
# Out:
# Index(['empid', 'ename', 'sal', 'address'], dtype='object')

# %%
df['ename']
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    r
# Name: ename, dtype: object

# %%
df[['ename','sal']]
# Out:
#   ename   sal
# 0     a  2300
# 1     b   900
# 2     c  1999
# 3     d  1888
# 4     r  1999

# %%
#df.sal
x=df[['empid','sal']]
x
# Out:
#    empid     sal
# 0      1  2300.0
# 1      2   900.0
# 2      3     NaN
# 3      4  1888.0
# 4      5  1999.0
# 5      6  4555.0
# 6      7  2333.0
# 7      8  4545.0
# 8      9  3434.0

# %%
df.describe() # statistical operations
# Out:
#           empid          sal
# count  5.000000     5.000000
# mean   3.000000  1817.200000
# std    1.581139   535.132414
# min    1.000000   900.000000
# 25%    2.000000  1888.000000
# 50%    3.000000  1999.000000
# 75%    4.000000  1999.000000
# max    5.000000  2300.000000

# %%
df.sal
# Out:
# 0    2300
# 1     900
# 2    1999
# 3    1888
# 4    1999
# Name: sal, dtype: int64

# %%
df.sal>2000
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# Name: sal, dtype: bool

# %%
df['ename'][df.sal>2000]
# Out:
# 0      a
# 5    NaN
# 6      g
# 7      c
# 8      m
# Name: ename, dtype: object

# %%
df[df.sal==df.sal.max()]
# Out:
#    empid ename     sal address
# 5      6   NaN  4555.0     NaN

# %%
df[['ename','sal']][df.sal==df.sal.max()]
# Out:
#   ename   sal
# 0     a  2300

# %%
df
# Out:
#    empid ename   sal  address
# 0      1     a  2300  kolkata
# 1      2     b   900   mumbai
# 2      3     c  1999    delhi
# 3      4     d  1888  chennai
# 4      5     r  1999     pune

# %%
df1=df.set_index('empid')
df1
# Out:
#       ename   sal  address
# empid
# 1         a  2300  kolkata
# 2         b   900   mumbai
# 3         c  1999    delhi
# 4         d  1888  chennai
# 5         r  1999     pune

# %%
df1=df.sort_values('address')
df1
# Out:
#    empid ename     sal  address
# 3      4     d  1888.0  chennai
# 6      7     g  2333.0  chennai
# 2      3     c     NaN    delhi
# 7      8     c  4545.0    delhi
# 0      1     a  2300.0  kolkata
# 1      2     b   900.0   mumbai
# 4      5     r  1999.0     pune
# 5      6   NaN  4555.0      NaN
# 8      9     m  3434.0      NaN

# %%
df
# Out:
#    empid ename   sal  address
# 0      1     a  2300  kolkata
# 1      2     b   900   mumbai
# 2      3     c  1999    delhi
# 3      4     d  1888  chennai
# 4      5     r  1999     pune

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df
# Out:
#    empid ename   sal  address
# 0      1     a  2300  kolkata
# 1      2     b   900   mumbai
# 2      3     c  1999    delhi
# 3      4     d  1888  chennai
# 4      5     r  1999     pune
# 5      6   NaN  4555      NaN
# 6      7     g  2333  chennai
# 7      8     c  4545    delhi
# 8      9     m  3434      NaN

# %%
df1=df.fillna(0) #fill 0 in NA values
df1
# Out:
#    empid ename   sal  address
# 0      1     a  2300  kolkata
# 1      2     b   900   mumbai
# 2      3     c  1999    delhi
# 3      4     d  1888  chennai
# 4      5     r  1999     pune
# 5      6     0  4555        0
# 6      7     g  2333  chennai
# 7      8     c  4545    delhi
# 8      9     m  3434        0

# %%
df1=df.fillna({'ename':'Name Missing', 'sal':0.0, 'address':'Invalid address'})
df1
# Out:
#    empid         ename     sal          address
# 0      1             a  2300.0          kolkata
# 1      2             b   900.0           mumbai
# 2      3             c     0.0            delhi
# 3      4             d  1888.0          chennai
# 4      5             r  1999.0             pune
# 5      6  Name Missing  4555.0  Invalid address
# 6      7             g  2333.0          chennai
# 7      8             c  4545.0            delhi
# 8      9             m  3434.0  Invalid address

# %%
df2=df.dropna()  #remove the rows which contains Null values
df2
# Out:
#    empid ename     sal  address
# 0      1     a  2300.0  kolkata
# 1      2     b   900.0   mumbai
# 3      4     d  1888.0  chennai
# 4      5     r  1999.0     pune
# 6      7     g  2333.0  chennai
# 7      8     c  4545.0    delhi

# %%
#Titanic
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[20:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...

# %%
df[20:30]
# Out:
# Empty DataFrame
# Columns: [empid, ename, sal, address]
# Index: []

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(df.shape)
# Out:
# (891, 12)

# %%
df.info() #meta info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum() # no. of rows contains nullvalue under each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
len(df[df['Survived']==1])
# Out:
# 342

# %%
len(df[df['Survived']==0])
# Out:
# 549

# %%
survived_df=df[df['Survived']==1]
survived_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
died_df=df[df['Survived']==0]
died_df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=df[['Name','Age']][df['Survived']==1]
df2
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 889                              Behr, Mr. Karl Howell  26.0
#
# [342 rows x 2 columns]

# %%
df_d=df[['Name','Age']][df['Survived']==0]
df_d
# Out:
#                                          Name   Age
# 0                     Braund, Mr. Owen Harris  22.0
# 4                    Allen, Mr. William Henry  35.0
# 5                            Moran, Mr. James   NaN
# 6                     McCarthy, Mr. Timothy J  54.0
# 7              Palsson, Master. Gosta Leonard   2.0
# ..                                        ...   ...
# 884                    Sutehall, Mr. Henry Jr  25.0
# 885      Rice, Mrs. William (Margaret Norton)  39.0
# 886                     Montvila, Rev. Juozas  27.0
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                       Dooley, Mr. Patrick  32.0
#
# [549 rows x 2 columns]

# %%
df_d.head(30)
# Out:
#                                                  Name   Age
# 0                             Braund, Mr. Owen Harris  22.0
# 4                            Allen, Mr. William Henry  35.0
# 5                                    Moran, Mr. James   NaN
# 6                             McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master. Gosta Leonard   2.0
# 12                     Saundercock, Mr. William Henry  20.0
# 13                        Andersson, Mr. Anders Johan  39.0
# 14               Vestrom, Miss. Hulda Amanda Adolfina  14.0
# 16                               Rice, Master. Eugene   2.0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0
# 20                               Fynney, Mr. Joseph J  35.0
# 24                      Palsson, Miss. Torborg Danira   8.0
# 26                            Emir, Mr. Farred Chehab   NaN
# 27                     Fortune, Mr. Charles Alexander  19.0
# 29                                Todoroff, Mr. Lalio   NaN
# ...

# %%
df1=df['Age'].dropna()
df1
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
import seaborn as sns

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
sns.displot(data=df, x='Age',bins=10,kde=True, color='red')

# %%
survived_df=df[df['Survived']==1]
sns.countplot(data=survived_df, x=survived_df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data=survived_df, x=survived_df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>
